# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, precision_score, recall_score, auc,roc_curve
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
brain = pd.read_csv('C:/Users/Basit/Downloads/brain_stroke_in_numeric_without_useless_data22.csv')
brain = brain[["gender",  "age",  "hypertension",  "heart_disease" , "ever_married", "avg_glucose_level" ,  "bmi",  "smoking_status" , "stroke"  ]]

X = brain.iloc[:, [5,6]].to_numpy()
y = brain.iloc[:, 8].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

scaler = MinMaxScaler() #saga solver requires features to be scaled for model conversion

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

print('Accuracy of logistic regression classifier on train set: {:.2f}'.format(logreg.score(X_train, y_train)))
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
print('Precision of logistic regression classifier on test set: {:.2f}'.format(precision_score(y_test, y_pred)))
# Out:
# Accuracy of logistic regression classifier on train set: 0.95
# Accuracy of logistic regression classifier on test set: 0.95
# Precision of logistic regression classifier on test set: 0.00
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Baseline comparison for any improvements we yield during the optimization work.

# %% [markdown]
# #C (or regularization strength) must be a positive float. Regularization strength works with the penalty to regulate overfitting. Smaller values specify stronger regularization and high value tells the model to give high weight to the training data.

# %% [markdown]
# The model performs well on the train and testings sets, and both yield a similar accuracy of 0.95, and at a glance, there is no overfitting occur. Therefore, we start by selecting the best solver excluding regularization at this stage: {‘newton-cg’, ‘lbfgs’, ‘sag’, ‘saga’}.

# %%
clf = [
    LogisticRegression(solver='newton-cg',penalty='none',max_iter=1000),
    LogisticRegression(solver='lbfgs',penalty='none',max_iter=1000),
    LogisticRegression(solver='sag',penalty='none',max_iter=1000),
    LogisticRegression(solver='saga',penalty='none',max_iter=1000)
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)

    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#    Train Accuracy  Test Accuracy  Precission  Recall  AUC
# 0         0.95123        0.94783         0.0     0.0  0.5
# 1         0.95123        0.94783         0.0     0.0  0.5
# 2         0.95123        0.94783         0.0     0.0  0.5
# 3         0.95123        0.94783         0.0     0.0  0.5

# %% [markdown]
# What we observe here is that regardless of the solver we choose, the model metric improvement vs baseline is less than 0.001%.

# %%
lf = [
    LogisticRegression(solver='newton-cg',penalty='l2', C=0.001, max_iter=1000),
    LogisticRegression(solver='lbfgs',penalty='l2',C=0.001, max_iter=1000),
    LogisticRegression(solver='sag',penalty='l2',C=0.001, max_iter=1000),
    LogisticRegression(solver='saga',penalty='l2',C=0.001, max_iter=1000)
    ]
clf_columns = []
clf_compare = pd.DataFrame(columns = clf_columns)

row_index = 0
for alg in clf:
        
    predicted = alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    clf_name = alg.__class__.__name__
    clf_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 5)
    clf_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 5)
    clf_compare.loc[row_index, 'Precission'] = round(precision_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'Recall'] = round(recall_score(y_test, predicted),5)
    clf_compare.loc[row_index, 'AUC'] = round(auc(fp, tp),5)

    row_index+=1
    
clf_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
clf_compare
# Out:
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#    Train Accuracy  Test Accuracy  Precission  Recall  AUC
# 0         0.95123        0.94783         0.0     0.0  0.5
# 1         0.95123        0.94783         0.0     0.0  0.5
# 2         0.95123        0.94783         0.0     0.0  0.5
# 3         0.95123        0.94783         0.0     0.0  0.5

# %% [markdown]
# we can conclude we didn’t gain any substantial benefit in building a better model while tuning the hyperparameters, and the classifier with default parameters was strong enough by itself.

# %%
LR = LogisticRegression()
LRparam_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'penalty': ['l1', 'l2'],
    # 'max_iter': list(range(100,800,100)),
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}
LR_search = GridSearchCV(LR, param_grid=LRparam_grid, refit = True, verbose = 3, cv=5)

# fitting the model for grid search 
LR_search.fit(X_train , y_train)
LR_search.best_params_
# summarize
print('Mean Accuracy: %.3f' % LR_search.best_score_)
print('Config: %s' % LR_search.best_params_)
# Out:
# Fitting 5 folds for each of 70 candidates, totalling 350 fits
# [CV 1/5] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END ...C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ...C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ...C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ...C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ...C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END .....C=0.001, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END .....C=0.001, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END .....C=0.001, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END .....C=0.001, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END .....C=0.001, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END ..C=0.001, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ..C=0.001, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ..C=0.001, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ..C=0.001, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ..C=0.001, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=0.001, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.001, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.001, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.001, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.001, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 1/5] END .C=0.001, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 2/5] END .C=0.001, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 3/5] END .C=0.001, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 4/5] END .C=0.001, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 5/5] END .C=0.001, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 1/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END ...C=0.001, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 2/5] END ...C=0.001, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 3/5] END ...C=0.001, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 4/5] END ...C=0.001, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 5/5] END ...C=0.001, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 1/5] END ..C=0.001, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ..C=0.001, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ..C=0.001, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ..C=0.001, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ..C=0.001, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=0.01, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.01, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.01, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.01, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.01, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END ....C=0.01, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ....C=0.01, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ....C=0.01, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ....C=0.01, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ....C=0.01, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END ......C=0.01, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END ......C=0.01, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END ......C=0.01, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END ......C=0.01, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END ......C=0.01, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END ...C=0.01, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ...C=0.01, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ...C=0.01, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ...C=0.01, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ...C=0.01, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=0.01, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.01, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.01, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.01, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.01, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 1/5] END ..C=0.01, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 2/5] END ..C=0.01, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 3/5] END ..C=0.01, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 4/5] END ..C=0.01, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 5/5] END ..C=0.01, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 1/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END ....C=0.01, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 2/5] END ....C=0.01, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 3/5] END ....C=0.01, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 4/5] END ....C=0.01, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 5/5] END ....C=0.01, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 1/5] END ...C=0.01, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ...C=0.01, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ...C=0.01, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ...C=0.01, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ...C=0.01, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END .C=0.1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END .C=0.1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END .C=0.1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END .C=0.1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END .C=0.1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END .......C=0.1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END .......C=0.1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END .......C=0.1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END .......C=0.1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END .......C=0.1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END ....C=0.1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ....C=0.1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ....C=0.1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ....C=0.1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ....C=0.1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=0.1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 1/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 2/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 3/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 4/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 5/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 1/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END .....C=0.1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 2/5] END .....C=0.1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 3/5] END .....C=0.1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 4/5] END .....C=0.1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 5/5] END .....C=0.1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 1/5] END ....C=0.1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ....C=0.1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ....C=0.1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ....C=0.1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ....C=0.1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END ...C=1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END ...C=1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END ...C=1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END ...C=1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END ...C=1, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END .C=1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END .C=1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END .C=1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END .C=1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END .C=1, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END .........C=1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END .........C=1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END .........C=1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END .........C=1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END .........C=1, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END ......C=1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ......C=1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ......C=1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ......C=1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ......C=1, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END .C=1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 2/5] END .C=1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 3/5] END .C=1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 4/5] END .C=1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 5/5] END .C=1, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 1/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 2/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 3/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 4/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 5/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 1/5] END .C=1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END .C=1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END .C=1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END .C=1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END .C=1, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END .......C=1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 2/5] END .......C=1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 3/5] END .......C=1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 4/5] END .......C=1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 5/5] END .......C=1, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 1/5] END ......C=1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ......C=1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ......C=1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ......C=1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ......C=1, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END ..C=10, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END ..C=10, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END ..C=10, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END ..C=10, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END ..C=10, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=10, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=10, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=10, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=10, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END ........C=10, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END ........C=10, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END ........C=10, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END ........C=10, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END ........C=10, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END .....C=10, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END .....C=10, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END .....C=10, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END .....C=10, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END .....C=10, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=10, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 2/5] END C=10, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 3/5] END C=10, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 4/5] END C=10, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 5/5] END C=10, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 1/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 2/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 3/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 4/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 5/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 1/5] END C=10, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=10, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=10, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=10, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=10, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END ......C=10, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 2/5] END ......C=10, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 3/5] END ......C=10, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 4/5] END ......C=10, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 5/5] END ......C=10, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 1/5] END .....C=10, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END .....C=10, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END .....C=10, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END .....C=10, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END .....C=10, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END .C=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END .C=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END .C=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END .C=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END .C=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END .....C=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END .....C=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END .....C=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END .....C=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END .....C=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=100, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=100, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=100, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=100, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=100, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END .......C=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END .......C=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END .......C=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END .......C=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END .......C=100, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END ....C=100, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ....C=100, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ....C=100, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ....C=100, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ....C=100, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=100, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 2/5] END C=100, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 3/5] END C=100, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 4/5] END C=100, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 5/5] END C=100, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 1/5] END ...C=100, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 2/5] END ...C=100, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 3/5] END ...C=100, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 4/5] END ...C=100, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 5/5] END ...C=100, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 1/5] END C=100, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=100, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=100, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=100, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=100, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END .....C=100, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 2/5] END .....C=100, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 3/5] END .....C=100, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 4/5] END .....C=100, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 5/5] END .....C=100, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 1/5] END ....C=100, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ....C=100, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ....C=100, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ....C=100, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ....C=100, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=1000, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END ....C=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ....C=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ....C=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ....C=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ....C=1000, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=1000, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=1000, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=1000, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=1000, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=1000, penalty=l1, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END ......C=1000, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END ......C=1000, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END ......C=1000, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END ......C=1000, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END ......C=1000, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END ...C=1000, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ...C=1000, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ...C=1000, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ...C=1000, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ...C=1000, penalty=l1, solver=saga;, score=0.951 total time=   0.0s
# [CV 1/5] END C=1000, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 2/5] END C=1000, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 3/5] END C=1000, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 4/5] END C=1000, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 5/5] END C=1000, penalty=l2, solver=newton-cg;, score=0.951 total time=   0.0s
# [CV 1/5] END ..C=1000, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 2/5] END ..C=1000, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 3/5] END ..C=1000, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 4/5] END ..C=1000, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 5/5] END ..C=1000, penalty=l2, solver=lbfgs;, score=0.951 total time=   0.0s
# [CV 1/5] END C=1000, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 2/5] END C=1000, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 3/5] END C=1000, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 4/5] END C=1000, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 5/5] END C=1000, penalty=l2, solver=liblinear;, score=0.951 total time=   0.0s
# [CV 1/5] END ....C=1000, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 2/5] END ....C=1000, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 3/5] END ....C=1000, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 4/5] END ....C=1000, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 5/5] END ....C=1000, penalty=l2, solver=sag;, score=0.951 total time=   0.0s
# [CV 1/5] END ...C=1000, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 2/5] END ...C=1000, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 3/5] END ...C=1000, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 4/5] END ...C=1000, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# [CV 5/5] END ...C=1000, penalty=l2, solver=saga;, score=0.951 total time=   0.0s
# Mean Accuracy: 0.951
# Config: {'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 105 fits failed out of a total of 350.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Basit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Basit\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.95123349        nan 0.95123349 0.95123349
#  0.95123349 0.95123349 0.95123349 0.95123349        nan        nan
#  0.95123349        nan 0.95123349 0.95123349 0.95123349 0.95123349
#  0.95123349 0.95123349        nan        nan 0.95123349        nan
#  0.95123349 0.95123349 0.95123349 0.95123349 0.95123349 0.95123349
#         nan        nan 0.95123349        nan 0.95123349 0.95123349
#  0.95123349 0.95123349 0.95123349 0.95123349        nan        nan
#  0.95123349        nan 0.95123349 0.95123349 0.95123349 0.95123349
#  0.95123349 0.95123349        nan        nan 0.95123349        nan
#  0.95123349 0.95123349 0.95123349 0.95123349 0.95123349 0.95123349
#         nan        nan 0.95123349        nan 0.95123349 0.95123349
#  0.95123349 0.95123349 0.95123349 0.95123349]
#   warnings.warn(
